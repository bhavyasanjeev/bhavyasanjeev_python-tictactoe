# %% [markdown]
# # tic tac toe with ai

# %%
##### print ("Welcome to Tic Tac Toe!")
board = [' ',' ',' ',' ',' ',' ',' ',' ',' ']

#no grid needed, use list index
def tutgrid():
    # This draws a grid
    print('\t│\t│\t\n   {}\t│   {}\t│   {}\n\t|\t|\t'.format(7,8,9))
    print("-------------------------")
    print('\t|\t|\t\n   {}\t|   {}\t|   {}\n\t|\t|\t'.format(4,5,6))
    print("-------------------------")
    print('\t|\t|\t\n   {}\t|   {}\t|   {}\n\t|\t|\t\n\n'.format(1,2,3))
print("You will play with numbers. This is how your number corresponds to the grid:")
tutgrid() 

# GRID
#This is the function that draws a grid using the board list
def realgrid():
    # This draws a grid
    print('\t|\t|\t\n   {}\t|   {}\t|   {}\n\t|\t|\t'.format(board[6],board[7],board[8]))
    print("-------------------------")
    print('\t|\t|\t\n   {}\t|   {}\t|   {}\n\t|\t|\t'.format(board[3],board[4],board[5]))
    print("-------------------------")
    print('\t|\t|\t\n   {}\t|   {}\t|   {}\n\t|\t|\t\n\n'.format(board[0],board[1],board[2])) 

# USER INTERACT
def choosesymbol():
    #character that isn't 'o' or 'x'
    symbol = "p"
    while symbol not in 'XO':
        symbol = (input("Will you be \'✕\', or \'◯\'? ")).upper()
        if symbol not in 'XO':
            print("Invalid input: Please try again.")
    if symbol == 'X':
        playersymbol = '✕'
        compsymbol = '◯'
        #check which symbol the player is
    else:
        playersymbol = '◯'
        compsymbol = '✕'
    return [playersymbol, compsymbol]

#================ the INTRODUCTION ==========
#code that must follow choosesymbol()
thesymbols = choosesymbol()
# playersymbol and compsymbol must be used here
playersymbol = thesymbols[0]
compsymbol = thesymbols[1]
print('You are \'{}\'.\nThe computer is \'{}\'.'.format(playersymbol, compsymbol))



# ==================== CHOOSE STARTING PLAYER =====================
import random
def chooseplayer():
    whofirst = random.choice(['Player', 'Computer'])
    return whofirst
whofirst = chooseplayer()
print ("{} goes first.".format(whofirst))
# whofirst holds value of starting player.

#==================== PLAYER MOVE DEFINE ===========================
def playermove():
    goodspot = False
    while goodspot == False:
        symlocat = int(input("Pick where you want to place your symbol (1-9)"))
        if board[symlocat-1] == playersymbol or board[symlocat-1] == compsymbol:
            print("That space is taken!, Pick somewhere else!")
        else:
            board[symlocat-1] = playersymbol
            goodspot = True
            realgrid()
        
#==================== COMPUTER MOVE DEFINE===========================
def compmove():
    goodspot = False
    while goodspot == False:
        symlocat = random.randint(1,9)
        if board[symlocat-1] == playersymbol or board[symlocat-1] == compsymbol:
            goodspot = False
        else:
            goodspot = True
            board[symlocat-1] = compsymbol
            realgrid()

# ==================== WIN CONDITION CHECKER DEFINED ==========================
def checkwinner(board, le):
    # Given a board and a player's letter, this function returns True if that player has won.
    # We use bo instead of board and le instead of letter so we don't have to type as much.
    return ((board[6] == le and board[7] == le and board[8] == le) or # across the top
    (board[3] == le and board[4] == le and board[5] == le) or # across the middle
    (board[0] == le and board[1] == le and board[2] == le) or # across the bottom
    (board[6] == le and board[3] == le and board[0] == le) or # down the left side
    (board[7] == le and board[4] == le and board[1] == le) or # down the middle
    (board[8] == le and board[5] == le and board[2] == le) or # down the right side
    (board[6] == le and board[4] == le and board[2] == le) or # diagonal
    (board[8] == le and board[4] == le and board[0] == le)) # diagonal
def wincheckp():
    return checkwinner(board, playersymbol)
def wincheckc():
    return checkwinner(board, compsymbol)

#============================== Tie checker def==============================
def tiecheck():
    tally = 0
    for i in board:
        if i != ' ':
            tally += 1
    if tally == 9:
        return True
    else:
        return False
#========================= START THE REAL GAME ======================
if whofirst == 'Player':
    playermove()
else:
    compmove()
        
#========================== CONTINUOUS PLAY WITH A CHECK FOR WIN AT THE ENDS ============
#===================================== or REGULAR PLAY LOOP =============================
win = False
while win == False:
    tie = tiecheck()
    if tie == True:
        print("It's a tie!")
        win = True
    elif whofirst == 'Player':
        print("Computer's turn:")
        compmove()
        winny = wincheckc()
        if winny == True:
            print ("You lose!")
            win = True
        #elif tie == True:
        #    print("It's a tie!")
        #    win = True
        else:
            print("Your turn:")
            playermove()
            winny = wincheckp()
            if winny == True:
                print("You win!")
                win = True
    else:
        playermove()
        winny = wincheckp()
        if winny == True:
            print("You win!")
            win = True
        #elif tie == True:
        #    print("It's a tie!")
        #    win = True
        else:
            print("Computer's turn:")
            compmove()
            winny = wincheckc()
            if winny == True:
                print("You lose!")
                win = True

# %%
def checkmate(board, le):
    # Given a board and a player's letter, this function returns True if the player has reached
    # We use bo instead of board and le instead of letter so we don't have to type as much.
    return  # across the top
    ((board[7] == le and board[8] == le and board[6] == ' ') or
    ((board[6] == le and board[7] == le and board[8] == ' ') or
    ((board[6] == le and board[8] == le and board[7] == ' ') or
     # across the middle
    (board[3] == le and board[4] == le and board[5] == ' ') or
    (board[4] == le and board[5] == le and board[3] == ' ') or
    (board[3] == le and board[5] == le and board[4] == ' ') or
     #across the bottom
    (board[0] == le and board[1] == le and board[2] == ' ') or 
    (board[1] == le and board[2] == le and board[0] == ' ') or
    (board[0] == le and board[2] == le and board[1] == ' ') or
     # down the left side
    (board[6] == le and board[3] == le and board[0] == ' ') or 
    (board[3] == le and board[0] == le and board[6] == ' ') or 
    (board[6] == le and board[0] == le and board[3] == ' ') or 
     # down the middle
    (board[7] == le and board[4] == le and board[1] == ' ') or
    (board[4] == le and board[1] == le and board[7] == ' ') or
    (board[7] == le and board[1] == le and board[4] == ' ') or
     # down the right side
    (board[8] == le and board[5] == le and board[2] == ' ') or 
    (board[5] == le and board[2] == le and board[8] == ' ') or 
    (board[8] == le and board[2] == le and board[5] == ' ') or 
     # diagonal
    (board[6] == le and board[4] == le and board[2] == ' ') or 
    (board[4] == le and board[2] == le and board[6] == ' ') or 
     # diagonal
    (board[8] == le and board[4] == le and board[0] == ' ') or
    (board[4] == le and board[0] == le and board[8] == ' '))

checkmate(board, playersymbol)
# Out:
#   File "<ipython-input-6-fb6fd4fc6e32>", line 35
#     checkmate(board, playersymbol)
#             ^
# SyntaxError: invalid syntax

# %%
def checkmatee(board, le):
    # Given a board and a player's letter, this function returns True if the player has reached
    # We use bo instead of board and le instead of letter so we don't have to type as much.
    return  # across the top
    ((board[7] == le and board[8] == le and board[6] == ' ') or
    (board[6] == le and board[7] == le and board[8] == ' ') or
    (board[6] == le and board[8] == le and board[7] == ' ') or
     # across the middle
    (board[3] == le and board[4] == le and board[5] == ' ') or
    (board[4] == le and board[5] == le and board[3] == ' ') or
    (board[3] == le and board[5] == le and board[4] == ' ') or
     #across the bottom
    (board[0] == le and board[1] == le and board[2] == ' ') or 
    (board[1] == le and board[2] == le and board[0] == ' ') or
    (board[0] == le and board[2] == le and board[1] == ' ') or
     # down the left side
    (board[6] == le and board[3] == le and board[0] == ' ') or 
    (board[3] == le and board[0] == le and board[6] == ' ') or 
    (board[6] == le and board[0] == le and board[3] == ' ') or 
     # down the middle
    (board[7] == le and board[4] == le and board[1] == ' ') or
    (board[4] == le and board[1] == le and board[7] == ' ') or
    (board[7] == le and board[1] == le and board[4] == ' ') or
     # down the right side
    (board[8] == le and board[5] == le and board[2] == ' ') or 
    (board[5] == le and board[2] == le and board[8] == ' ') or 
    (board[8] == le and board[2] == le and board[5] == ' ') or 
     # diagonal
    (board[6] == le and board[4] == le and board[2] == ' ') or 
    (board[4] == le and board[2] == le and board[6] == ' ') or 
     # diagonal
    (board[8] == le and board[4] == le and board[0] == ' ') or
    (board[4] == le and board[0] == le and board[8] == ' '))

checkmatee(board, playersymbol)
